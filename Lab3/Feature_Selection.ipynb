# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import mutual_info_classif

# %% [markdown]
# ## Importing dataset

# %%
df = pd.read_excel("./Bean/Drybean.xlsx")
# df_class1 = pd.read_excel("./Bean/Drybean_seker.xlsx")

# %% [markdown]
# ## Prints the summary statistics for each numerical column

# %%
df.describe()
# Out:
#                 Area    Perimeter  MajorAxisLength  MinorAxisLength  \
# count    3871.000000  3871.000000      3871.000000      3871.000000
# mean    68116.677861   952.114961       337.946969       238.277411
# std     45136.248207   298.804792       118.384794        58.837589
# min     28395.000000   610.291000       200.524796       171.210559
# 25%     38939.000000   718.730000       248.228227       199.750599
# 50%     48327.000000   817.975000       286.917253       215.770799
# 75%     73402.500000  1081.353000       383.019675       248.449571
# max    254616.000000  1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter       Extent  \
# count   3871.000000   3871.000000    3871.000000    3871.000000  3871.000000
# mean       1.393265      0.667845   69051.117024     282.563441     0.764683
# std        0.187455      0.106558   45809.004249      82.997165     0.032746
# min        1.024868      0.218951   28715.000000     190.141097     0.607021
# 25%        1.231043      0.583213   39299.500000     222.662692     0.748256
# 50%        1.347144      0.670055   48849.000000     248.056138     0.770739
# 75%        1.550851      0.764345   74729.000000     305.710591     0.786427
# max        1.950371      0.858554  263261.000000     569.374358     0.858420
#
#           Solidity    roundness  Compactness  ShapeFactor1  ShapeFactor2  \
# count  3871.000000  3871.000000  3871.000000   3871.000000   3871.000000
# mean      0.987308     0.884425     0.851422      0.005611      0.001920
# std       0.005075     0.076212     0.056784      0.001031      0.000725
# min       0.919246     0.593708     0.713613      0.002778      0.000564
# 25%       0.984170     0.825196     0.801010      0.005152      0.001300
# 50%       0.989002     0.902624     0.859652      0.005914      0.002009
# 75%       0.991198     0.952528     0.900429      0.006386      0.002560
# max       0.994677     0.990685     0.987303      0.007474      0.003665
#
#        ShapeFactor3  ShapeFactor4
# count   3871.000000   3871.000000
# mean       0.728144      0.996598
# std        0.096223      0.003348
# min        0.509244      0.947687
# 25%        0.641616      0.995654
# 50%        0.739002      0.997783
# 75%        0.810773      0.998717
# max        0.974767      0.999733

# %% [markdown]
# ## The head function prints the first n-rows. (default = 5)

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER

# %% [markdown]
# ## Prints basic info about the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3871 entries, 0 to 3870
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             3871 non-null   int64
#  1   Perimeter        3871 non-null   float64
#  2   MajorAxisLength  3871 non-null   float64
#  3   MinorAxisLength  3871 non-null   float64
#  4   AspectRation     3871 non-null   float64
#  5   Eccentricity     3871 non-null   float64
#  6   ConvexArea       3871 non-null   int64
#  7   EquivDiameter    3871 non-null   float64
#  8   Extent           3871 non-null   float64
#  9   Solidity         3871 non-null   float64
#  10  roundness        3871 non-null   float64
#  11  Compactness      3871 non-null   float64
#  12  ShapeFactor1     3871 non-null   float64
#  13  ShapeFactor2     3871 non-null   float64
#  14  ShapeFactor3     3871 non-null   float64
#  15  ShapeFactor4     3871 non-null   float64
#  16  Class            3871 non-null   object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 514.2+ KB

# %%
# label_encoder = LabelEncoder()
# df['Class'] = label_encoder.fit_transform(df['Class'])

# %%
df["Class"].unique()
# Out:
# array(['SEKER', 'BARBUNYA', 'BOMBAY'], dtype=object)

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()

# %%
df1["Class"]=(df1["Class"] == "SEKER").astype(int)

# %%
corr_matrix = df1.corr()
corr_matrix["Class"].sort_values(ascending=False)
# Out:
# Class              1.000000
# ShapeFactor2       0.896954
# ShapeFactor3       0.839155
# Compactness        0.838707
# roundness          0.826655
# ShapeFactor1       0.736126
# Solidity           0.628639
# ShapeFactor4       0.559071
# Extent             0.223890
# MinorAxisLength   -0.648133
# Area              -0.655950
# ConvexArea        -0.658819
# EquivDiameter     -0.727905
# MajorAxisLength   -0.767539
# Perimeter         -0.787626
# Eccentricity      -0.817392
# AspectRation      -0.828346
# Name: Class, dtype: float64

# %%
df2["Class"]=(df2["Class"] == "BARBUNYA").astype(int)

# %%
corr_matrix2 = df2.corr()
corr_matrix2["Class"].sort_values(ascending=False)
# Out:
# Class              1.000000
# Eccentricity       0.586839
# AspectRation       0.580681
# Perimeter          0.226561
# MajorAxisLength    0.195281
# EquivDiameter      0.127981
# ConvexArea         0.031047
# Area               0.026927
# MinorAxisLength    0.024874
# ShapeFactor1      -0.176947
# ShapeFactor4      -0.184680
# Extent            -0.338945
# ShapeFactor2      -0.522711
# Compactness       -0.588818
# ShapeFactor3      -0.591334
# Solidity          -0.639290
# roundness         -0.795976
# Name: Class, dtype: float64

# %%
df3["Class"]=(df3["Class"] == "BOMBAY").astype(int)

# %%
corr_matrix3 = df3.corr()
corr_matrix3["Class"].sort_values(ascending=False)
# Out:
# Class              1.000000
# Area               0.921762
# ConvexArea         0.920237
# MinorAxisLength    0.913183
# EquivDiameter      0.886676
# MajorAxisLength    0.851191
# Perimeter          0.837135
# AspectRation       0.405024
# Eccentricity       0.380457
# Extent             0.143206
# Solidity          -0.031636
# roundness         -0.103641
# ShapeFactor3      -0.406039
# Compactness       -0.408876
# ShapeFactor4      -0.561081
# ShapeFactor2      -0.585829
# ShapeFactor1      -0.830714
# Name: Class, dtype: float64
