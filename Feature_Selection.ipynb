# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd

# %% [markdown]
# ## Importing dataset

# %%
df = pd.read_csv("/Users/asmithakrishnakumar/Downloads/wine/wine.data")

# %% [markdown]
# ## The head function prints the first n-rows. (default = 5)

# %%
df.head()
# Out:
#    Wine Type  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0          1    14.23        1.71  2.43               15.6        127
# 1          1    13.20        1.78  2.14               11.2        100
# 2          1    13.16        2.36  2.67               18.6        101
# 3          1    14.37        1.95  2.50               16.8        113
# 4          1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  Diluted wines  Proline
# 0             5.64  1.04           3.92     1065
# ...

# %% [markdown]
# ## Prints the summary statistics for each numerical column

# %%
df.describe()
# Out:
#         Wine Type     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %% [markdown]
# ## Determines shape of the Dataframe

# %%
df.shape
# Out:
# (178, 14)

# %% [markdown]
# ## Displays the column

# %%
df["Alcohol"]
# Out:
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: Alcohol, Length: 178, dtype: float64

# %%
df["Malic acid"]
# Out:
# 0      1.71
# 1      1.78
# 2      2.36
# 3      1.95
# 4      2.59
#        ...
# 173    5.65
# 174    3.91
# 175    4.28
# 176    2.59
# 177    4.10
# Name: Malic acid, Length: 178, dtype: float64

# %% [markdown]
# ## Displays information of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Wine Type             178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity of ash     178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  Diluted wines         178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %% [markdown]
# # Defining correlation

# %%
corr_matrix = df.corr()

# %% [markdown]
# ## Sorting the correlation values of the "Wine Type" column in a correlation matrix in descending order

# %%
corr_matrix["Wine Type"].sort_values(ascending=False)
# Out:
# Wine Type               1.000000
# Alcalinity of ash       0.517859
# Nonflavanoid phenols    0.489109
# Malic acid              0.437776
# Color intensity         0.265668
# Ash                    -0.049643
# Magnesium              -0.209179
# Alcohol                -0.328222
# Proanthocyanins        -0.499130
# Hue                    -0.617369
# Proline                -0.633717
# Total phenols          -0.719163
# Diluted wines          -0.788230
# Flavanoids             -0.847498
# Name: Wine Type, dtype: float64

# %% [markdown]
# ## Finding correlation for each classes in Wine Type

# %%
class_1_data = df[df['Wine Type'] == 1].drop('Wine Type', axis=1)
class_2_data = df[df['Wine Type'] == 2].drop('Wine Type', axis=1)
class_3_data = df[df['Wine Type'] == 3].drop('Wine Type', axis=1)

# Calculate the correlation for each class
correlation_class_1 = class_1_data.corr()
correlation_class_2 = class_2_data.corr()
correlation_class_3 = class_3_data.corr()

# Print the correlation matrices for each class
print("Correlation for Class 1:\n", correlation_class_1)
# Out:
# Correlation for Class 1:
#                         Alcohol  Malic acid       Ash  Alcalinity of ash  \
# Alcohol               1.000000   -0.040513 -0.148595          -0.318367
# Malic acid           -0.040513    1.000000  0.026221           0.060031
# Ash                  -0.148595    0.026221  1.000000           0.549330
# Alcalinity of ash    -0.318367    0.060031  0.549330           1.000000
# Magnesium             0.159361    0.079317  0.382549           0.238337
# Total phenols         0.420687   -0.083514  0.004802          -0.222999
# Flavanoids            0.414904   -0.191278 -0.070454          -0.287103
# Nonflavanoid phenols  0.015659   -0.089366  0.465901           0.302262
# Proanthocyanins       0.307571   -0.080798 -0.145471          -0.173628
# Color intensity       0.408291   -0.257587 -0.124220          -0.210951
# Hue                   0.080020   -0.419981  0.239214           0.092980
# Diluted wines         0.069818    0.173244 -0.081593          -0.117704
# ...

# %%
print("\nCorrelation for Class 2:\n", correlation_class_2)
# Out:
# Correlation for Class 2:
#                         Alcohol  Malic acid       Ash  Alcalinity of ash  \
# Alcohol               1.000000   -0.021362 -0.214851          -0.056282
# Malic acid           -0.021362    1.000000  0.148708           0.237923
# Ash                  -0.214851    0.148708  1.000000           0.695264
# Alcalinity of ash    -0.056282    0.237923  0.695264           1.000000
# Magnesium            -0.029911   -0.076788  0.129130           0.003263
# Total phenols        -0.046321    0.039441  0.112146           0.127942
# Flavanoids           -0.038247    0.111932  0.314937           0.311356
# Nonflavanoid phenols -0.068159    0.127605  0.299757           0.182617
# Proanthocyanins      -0.189617    0.210541  0.042955           0.108838
# Color intensity       0.269789   -0.203258  0.060247          -0.085862
# Hue                  -0.002038   -0.407986 -0.031244          -0.076825
# Diluted wines        -0.130313    0.157838  0.160590           0.382078
# ...

# %%
print("\nCorrelation for Class 3:\n", correlation_class_3)
# Out:
# Correlation for Class 3:
#                         Alcohol  Malic acid       Ash  Alcalinity of ash  \
# Alcohol               1.000000    0.110465  0.245078           0.209946
# Malic acid            0.110465    1.000000  0.018057           0.085049
# Ash                   0.245078    0.018057  1.000000           0.758518
# Alcalinity of ash     0.209946    0.085049  0.758518           1.000000
# Magnesium            -0.084141   -0.174979  0.211286           0.159407
# Total phenols         0.210362   -0.160717  0.470437           0.364509
# Flavanoids            0.076087   -0.281573  0.277110           0.271450
# Nonflavanoid phenols  0.038158    0.142758 -0.020370          -0.017077
# Proanthocyanins       0.376559   -0.223447  0.193835           0.263398
# Color intensity       0.350378   -0.162205  0.125153           0.160620
# Hue                  -0.034147    0.079707  0.180470           0.027650
# Diluted wines         0.132150    0.007206  0.225396           0.041695
# ...

# %%
# Assume the features are in X and wine type is in y
X = df.iloc[:, :-1]  # Features
y = df["Wine Type"]  # Wine Type

# Filter the dataset for instances where "Wine Type" is equal to 1
X_filtered = X[y == 1]
y_filtered = y[y == 1]  # Wine Type for the filtered instances

# Compute the correlation of each feature with "Wine Type" (when Wine Type is 1)
correlation_with_wine_type = X_filtered.corrwith(y_filtered)

# Sort the correlations in descending order
correlation_with_wine_type_sorted = correlation_with_wine_type.sort_values(ascending=False)

print("Correlation with Wine Type when Wine Type is 1:")
print(correlation_with_wine_type_sorted)
# Out:
# Correlation with Wine Type when Wine Type is 1:
# Wine Type              NaN
# Alcohol                NaN
# Malic acid             NaN
# Ash                    NaN
# Alcalinity of ash      NaN
# Magnesium              NaN
# Total phenols          NaN
# Flavanoids             NaN
# Nonflavanoid phenols   NaN
# Proanthocyanins        NaN
# Color intensity        NaN
# Hue                    NaN
# Diluted wines          NaN
# dtype: float64

# %%
X = df.drop('Wine Type', axis=1)  # Features
y = df['Wine Type']  # Class labels

# Initialize dictionaries to store the top features for each class
top_features_2 = {}
top_features_5 = {}
top_features_10 = {}

# Calculate the correlation between features and class labels for each class
for wine_type in df['Wine Type'].unique():
    class_data = X[y == wine_type]
    correlations = class_data.corrwith(y[y == wine_type])
    top_features_2[wine_type] = correlations.abs().nlargest(2).index.tolist()
    top_features_5[wine_type] = correlations.abs().nlargest(5).index.tolist()
    top_features_10[wine_type] = correlations.abs().nlargest(10).index.tolist()

# Flatten the lists of top features
top_features_2_flat = [feat for sublist in top_features_2.values() for feat in sublist]
top_features_5_flat = [feat for sublist in top_features_5.values() for feat in sublist]
top_features_10_flat = [feat for sublist in top_features_10.values() for feat in sublist]

# Create three datasets based on selected features
data_set_1 = X[top_features_2_flat]
data_set_2 = X[top_features_5_flat]
data_set_3 = X[top_features_10_flat]

# You can also add the 'Wine Type' column back to these datasets if needed
data_set_1['Wine Type'] = y
data_set_2['Wine Type'] = y
data_set_3['Wine Type'] = y
# Out:
# /var/folders/ns/2s2gr1lj743948qmmjlvx2g00000gn/T/ipykernel_1645/2806598048.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_set_1['Wine Type'] = y
# /var/folders/ns/2s2gr1lj743948qmmjlvx2g00000gn/T/ipykernel_1645/2806598048.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_set_2['Wine Type'] = y
# /var/folders/ns/2s2gr1lj743948qmmjlvx2g00000gn/T/ipykernel_1645/2806598048.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
